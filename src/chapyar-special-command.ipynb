# %% [markdown]
# #### Run dbUpdater command

# %%
wd = 'C:\\Projects\\Chapyar\\chapyarvc\\dbUpdater\\bin\\Release\\'

import os
os.chdir(wd)

! dbupdater.exe -h .\sql2017 -d chapyar_1404 -r true -u user -l true -s ..\..\..\UpdateScripts

# %% [markdown]
# ## Copy requirements

# %% [markdown]
# Copy `Microsoft.mshtml` into build ouput directory

# %%
import shutil

src = "C:\\Projects\\Chapyar\\mChapyar - github\\packages\\Unofficial.Microsoft.mshtml.7.0.3300\\lib\\net40\\Microsoft.mshtml.dll"
dst = "C:\\Projects\\Chapyar\\mchapyar - github\\mchapyar\\bin\\Debug"

shutil.copy(src, dst)

# %% [markdown]
# Copy `reports` into build output directory:

# %%
import shutil

src = "C:\\Projects\\Chapyar\\mChapyar - github\\MYPreRequists\\reports"
dst = "C:\\Projects\\Chapyar\\mchapyar - github\\mchapyar\\bin\\Debug\\reports"

shutil.copytree(src, dst, dirs_exist_ok=True)

# %% [markdown]
# Copy `CreateDb_zero.sql` file

# %%
import shutil

src = "C:\\Projects\\Chapyar\\mChapyar - github\\MYPreRequists\\createDB_zero.sql"
dst = "C:\\Projects\\Chapyar\\mchapyar - github\\mchapyar\\bin\\Debug"

shutil.copy(src, dst)
# Out:
# 'C:\\Projects\\Chapyar\\mchapyar - github\\mchapyar\\bin\\Debug\\createDB_zero.sql'
